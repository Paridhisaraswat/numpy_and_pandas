# %% [markdown]
# # Introduction to pandas ::
# # pandas is an open - source library of python which is used for handle data manipulation

# %%
import pandas as pd

# %%
# data structure of pandas :
# (1) Series
# (2) DataFrame

# %%
# (1) Series ---> it is a one-dimentional array and it will return only values not column name

# %%
a = pd.Series([1,23,4,5,67,89])
a
# Out:
# 0     1
# 1    23
# 2     4
# 3     5
# 4    67
# 5    89
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#(2) DataFrame : it is multi-dimentional array and it return values with column name

# %%
# Task :: we have to create a dataframe of employees in which column are
# emp_id ,emp_name ,department , salary , working_hours

# %%
a = {
    "emp_id" :[101,102,103,104,105,106],
    "emp_name":["tanishq","sam","raghav","dev","daksh","karan"],
    "department" : ["it","it","operation","operation","it","operation"],
    "salary" : [20000,30000,40000,50000,19000,20000],
    "working_hours" : [8,9,8,9,8,9]
}

# %%
df = pd.DataFrame(a)
df
# Out:
#    emp_id emp_name department  salary  working_hours
# 0     101  tanishq         it   20000              8
# 1     102      sam         it   30000              9
# 2     103   raghav  operation   40000              8
# 3     104      dev  operation   50000              9
# 4     105    daksh         it   19000              8
# 5     106    karan  operation   20000              9

# %%
# how we can export our dataframe into csv data

# %%
df.to_csv("emp_info.csv")     ### to_csv ---> use to export your data into csv file

# %%
df.to_csv("emp.csv",index = False)    ##index=False ---> it will remove the unnamed column

# %%
#import data using read_csv

# %%
df = pd.read_csv("/content/emp.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2994100692.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/emp.csv")
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/amazon.csv",encoding = "latin-1")
df
# Out:
#                BRAND                                       DISCRIPTION   SIZE  \
# 0         OFF LIMITS  Men's Derek Plus Size Big and Tall Walking Sho...   3.8
# 1               YOHO  Blinc Hands Free Sneakers for Men | Truly Slip...   NaN
# 2         OFF LIMITS  Men's Ginza Big and Tall Sneakers, Casual, Spe...   5.0
# 3    U.S. POLO ASSN.    USPA|GREN| Stylish Casual Sneaker Shoes for Man   4.4
# 4               Nike                          Mens Revolution 8 Running   3.9
# 5               PUMA                   Mens Cricket Square Cricket Shoe   3.8
# 6               PUMA  Women, Club II Era Memoires, Haute Tropic-Berr...   NaN
# 7               PUMA                     Women Carina Slim Perf Sneaker   4.0
# 8        new balance      Mens M411YC3 Running Shoe White,8 UK (8.5 US)   NaN
# 9               PUMA                  Unisex-Adult Court Curves Sneaker   4.1
# 10          Skechers                      Men Summits Brisbane Sneakers   4.1
# ...

# %%
df = pd.read_csv("/content/mussoorie.csv")
df
# Out:
#               PLACES TO VISIT             RATING  \
# 0                      Landour  4.1 of 5 bubbles
# 1       Lal Tibba Scenic Point    4 of 5 bubbles
# 2       SOHAM Himalayan Centre  4.8 of 5 bubbles
# 3                 Kempty Falls  3.3 of 5 bubbles
# 4                  Cloud's End  4.1 of 5 bubbles
# 5            Camel's Back Road  4.1 of 5 bubbles
# 6                    Mall Road  3.9 of 5 bubbles
# 7               Company Garden  3.7 of 5 bubbles
# 8                 Bhatta Falls  3.9 of 5 bubbles
# 9          Jharipani Waterfall    4 of 5 bubbles
# 10                Happy Valley  4.4 of 5 bubbles
# 11                    Gun Hill  3.2 of 5 bubbles
# 12   Shedup Choepelling Temple  4.2 of 5 bubbles
# 13              Library Bazaar  3.7 of 5 bubbles
# 14           Jwala Devi Temple  4.4 of 5 bubbles
# 15         Santura Devi Temple  4.5 of 5 bubbles
# 16     Mussoorie Christ Church  4.1 of 5 bubbles
# 17                   Lake Mist  3.9 of 5 bubbles
# ...

# %%
df = pd.read_csv("/content/covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
### How can we check total columns in this dataframe

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
##### How can we check top 5 data from the dataframe ?

# %%
df.head(2)  ### it returns top 5 data by default and if pass value in this it will return that rows.
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
# How can we check bottom data from the dataframe ?

# %%
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.sample(3) ### random entries from the data set
# Out:
#     age  gender  fever   cough       city has_covid
# 62   56  Female  104.0  Strong  Bangalore       Yes
# 85   16  Female  103.0    Mild  Bangalore       Yes
# 95   12  Female  104.0    Mild  Bangalore        No

# %%
# How can we check datatype of all columns

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
# How can we check Statically view of dataframe ?

# %%
df.describe()
# Out:
#            emp_id        salary  working_hours
# count    6.000000      6.000000       6.000000
# mean   103.500000  29833.333333       8.500000
# std      1.870829  12812.754063       0.547723
# min    101.000000  19000.000000       8.000000
# 25%    102.250000  20000.000000       8.000000
# 50%    103.500000  25000.000000       8.500000
# 75%    104.750000  37500.000000       9.000000
# max    106.000000  50000.000000       9.000000

# %%
# How can we check overall information in the dataframe ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   emp_id         6 non-null      int64
#  1   emp_name       6 non-null      object
#  2   department     6 non-null      object
#  3   salary         6 non-null      int64
#  4   working_hours  6 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 372.0+ bytes

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
# How can we check missing values in a dataframe ?

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'].mean()
# Out:
# np.float64(100.84444444444445)

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
# How can we check total sub-categories in a column

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df['gender'] = df['gender'].map({"Male":0 , "Female":1})

# %%
df['cough'] = df['cough'].map({"Mild":0 , "Strong":1})

# %%
df['city'] = df['city'].map({"Kolkata":0 , "Bangalore":1 , "Delhi":2 , "Mumbai":3})

# %%
df['has_covid'] = df['has_covid'].map({"Yes":1 , "No":0})

# %%
df.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0    NaN     0          0
# 1   27       0  100.0    NaN     2          1
# 2   42       0  101.0    NaN     2          0

# %% [markdown]
# # Data :
# ### **Categorical(Descrete)** ---> We cannot divide furthur . Ex. has_covid(y,n), marital_status(y,n),result(p,f), students_in_class(50,51)
# ### #**Numerical(Continuous)** ---> We can divide furthur . Ex. distance jaipur to delhi(310.60km), weight(kg,gm), salary(rupees), Insurance_charges(rupees) , birth_year(25)

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
#fill null values with mean of the column

df["fever"] = df["fever"].fillna(df["fever"].mean())

# %%
# loc and iloc
# df.loc[row_range ,column_name] ---> include the last value also


# df.iloc[row_range,column_range]----> doesn't include the last value

# %%
df.loc[5:10 ,["age","fever"]]
# Out:
#     age       fever
# 5    84  100.844444
# 6    14  101.000000
# 7    20  100.844444
# 8    19  100.000000
# 9    64  101.000000
# 10   75  100.844444

# %%
df.iloc[5:10 ,[0]]
# Out:
#    age
# 5   84
# 6   14
# 7   20
# 8   19
# 9   64

# %%
df.iloc[2:5,0:4:2]
# Out:
#    age  fever
# 2   42  101.0
# 3   31   98.0
# 4   65  101.0

# %%
# update using iloc

df.iloc[5:10 ,[0,2]] = 55

# %%
df.head(11)
# Out:
#     age  gender       fever   cough       city has_covid
# 0    60    Male  103.000000    Mild    Kolkata        No
# 1    27    Male  100.000000    Mild      Delhi       Yes
# 2    42    Male  101.000000    Mild      Delhi        No
# 3    31  Female   98.000000    Mild    Kolkata        No
# 4    65  Female  101.000000    Mild     Mumbai        No
# 5    55  Female   55.000000    Mild  Bangalore       Yes
# 6    55    Male   55.000000  Strong  Bangalore        No
# 7    55  Female   55.000000  Strong     Mumbai       Yes
# 8    55  Female   55.000000  Strong  Bangalore        No
# 9    55  Female   55.000000    Mild      Delhi        No
# 10   75  Female  100.844444    Mild      Delhi        No

# %%
#counts the number of sub categories in a column

df["gender"].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({"Male":0 , "Female":1})
df['cough'] = df['cough'].map({"Mild":0 , "Strong":1})
df["has_covid"] = df["has_covid"].map({"yes": 1,"No":0})

# %%
df.tail()
# Out:
#     age  gender  fever  cough       city  has_covid
# 95   12       1  104.0      0  Bangalore        0.0
# 96   51       1  101.0      1    Kolkata        NaN
# 97   20       1  101.0      0  Bangalore        0.0
# 98    5       1   98.0      1     Mumbai        0.0
# 99   10       1   98.0      1    Kolkata        NaN

# %%
df.sample(3)
# Out:
#     age  gender  fever  cough       city  has_covid
# 76   80       0  100.0      0  Bangalore        NaN
# 0    60       0  103.0      0    Kolkata        0.0
# 80   14       1   99.0      0     Mumbai        NaN

# %%
#delete a column

df.drop(columns = ["city"])       #temporary
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0        0.0
# 1    27       0  100.0      0        NaN
# 2    42       0  101.0      0        0.0
# 3    31       1   98.0      0        0.0
# 4    65       1  101.0      0        0.0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0        0.0
# 96   51       1  101.0      1        NaN
# 97   20       1  101.0      0        0.0
# 98    5       1   98.0      1        0.0
# 99   10       1   98.0      1        NaN
#
# [100 rows x 5 columns]

# %%
df = df.drop(columns = ["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2811056770.py in <cell line: 0>()
# ----> 1 df = df.drop(columns = ["city"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.sort_index()     ###sort the data
# Out:
#     age  gender  fever  cough  has_covid
# 0    60       0  103.0      0        0.0
# 1    27       0  100.0      0        NaN
# 2    42       0  101.0      0        0.0
# 3    31       1   98.0      0        0.0
# 4    65       1  101.0      0        0.0
# ..  ...     ...    ...    ...        ...
# 95   12       1  104.0      0        0.0
# 96   51       1  101.0      1        NaN
# 97   20       1  101.0      0        0.0
# 98    5       1   98.0      1        0.0
# 99   10       1   98.0      1        NaN
#
# [100 rows x 5 columns]

# %%
#rename the column

df = df.rename(columns = {"cough":"updated_cough"})

# %%
df
# Out:
#     age  gender  fever  updated_cough  has_covid
# 0    60       0  103.0              0        0.0
# 1    27       0  100.0              0        NaN
# 2    42       0  101.0              0        0.0
# 3    31       1   98.0              0        0.0
# 4    65       1  101.0              0        0.0
# ..  ...     ...    ...            ...        ...
# 95   12       1  104.0              0        0.0
# 96   51       1  101.0              1        NaN
# 97   20       1  101.0              0        0.0
# 98    5       1   98.0              1        0.0
# 99   10       1   98.0              1        NaN
#
# [100 rows x 5 columns]

# %%
df["Age"] =df["age"].add(10)

# %%
df
# Out:
#     age  gender  fever  updated_cough  has_covid  Age
# 0    60       0  103.0              0        0.0   70
# 1    27       0  100.0              0        NaN   37
# 2    42       0  101.0              0        0.0   52
# 3    31       1   98.0              0        0.0   41
# 4    65       1  101.0              0        0.0   75
# ..  ...     ...    ...            ...        ...  ...
# 95   12       1  104.0              0        0.0   22
# 96   51       1  101.0              1        NaN   61
# 97   20       1  101.0              0        0.0   30
# 98    5       1   98.0              1        0.0   15
# 99   10       1   98.0              1        NaN   20
#
# [100 rows x 6 columns]

# %%
df["fever"] = df["fever"].sub(100)

# %%
df
# Out:
#     age  gender  fever  updated_cough  has_covid  Age
# 0    60       0    3.0              0        0.0   70
# 1    27       0    0.0              0        NaN   37
# 2    42       0    1.0              0        0.0   52
# 3    31       1   -2.0              0        0.0   41
# 4    65       1    1.0              0        0.0   75
# ..  ...     ...    ...            ...        ...  ...
# 95   12       1    4.0              0        0.0   22
# 96   51       1    1.0              1        NaN   61
# 97   20       1    1.0              0        0.0   30
# 98    5       1   -2.0              1        0.0   15
# 99   10       1   -2.0              1        NaN   20
#
# [100 rows x 6 columns]

# %%
df = df.drop(columns =[ "Age"])

# %%
df
# Out:
#     age  gender  fever  updated_cough  has_covid
# 0    60       0    3.0              0        0.0
# 1    27       0    0.0              0        NaN
# 2    42       0    1.0              0        0.0
# 3    31       1   -2.0              0        0.0
# 4    65       1    1.0              0        0.0
# ..  ...     ...    ...            ...        ...
# 95   12       1    4.0              0        0.0
# 96   51       1    1.0              1        NaN
# 97   20       1    1.0              0        0.0
# 98    5       1   -2.0              1        0.0
# 99   10       1   -2.0              1        NaN
#
# [100 rows x 5 columns]

# %%
df[["age","fever"]]    ###using this method , we can filter the data
# Out:
#     age  fever
# 0    60    3.0
# 1    27    0.0
# 2    42    1.0
# 3    31   -2.0
# 4    65    1.0
# ..  ...    ...
# 95   12    4.0
# 96   51    1.0
# 97   20    1.0
# 98    5   -2.0
# 99   10   -2.0
#
# [100 rows x 2 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(4)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 58  6.47          7.37       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.loc[2:4,["cgpa"]]
# Out:
#    cgpa
# 2  8.27
# 3  6.88
# 4  7.52

# %%
df.iloc[2:5,0:2]
# Out:
#    cgpa  resume_score
# 2  8.27          8.86
# 3  6.88          7.27
# 4  7.52          7.30

# %%
df.iloc[:4,:3]
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,["cgpa",'placed']]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
# axes ---> returns starting and ending  row index and their step value
# ----> all columns name
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty #it returns true if there any missing data in dataframe otherwise false
b
# Out:
# False

# %%
# checks for missings values
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
# remove the rows with missing elements
df = df.dropna()

# %%
# to check the dimensions
i = df.ndim
i
# Out:
# 2

# %%
t = df.shape # shape n(row) , n(columns)
t
# Out:
# (100, 3)

# %%
df.shape[0]    ### total num of rows
df.shape[1]    ### total num of colums
# Out:
# 5

# %%
# total num of elements
d = df.size
d
# Out:
# 300

# %%
s = df.values  ## get a numpy array for df w/o columns names just the values
s
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
# create copy of the dataframe
df = df.copy()

# %%
# sort the value
p = df.sort_values(by = "resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     16             6       1
# 1     14             5       0
# 2     16             8       1
# 3     14             7       1
# 4     15             7       1
# ..   ...           ...     ...
# 95    14             6       0
# 96    16             7       1
# 97    14             7       0
# 98    16             5       1
# 99    14             6       0
#
# [100 rows x 3 columns]

# %%
# to change datatype of the elements

df['cgpa'] = df['cgpa'].astype(int)

# %%
df['cgpa'] = df['cgpa'].astype(str)

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['resume_score'] =df['resume_score'].astype(int)

# %%
df['cgpa'] = df['cgpa'].astype(int)
df['cgpa'] = df['cgpa'].add(10)
df
# Out:
#     cgpa  resume_score  placed
# 0     26             6       1
# 1     24             5       0
# 2     26             8       1
# 3     24             7       1
# 4     25             7       1
# ..   ...           ...     ...
# 95    24             6       0
# 96    26             7       1
# 97    24             7       0
# 98    26             5       1
# 99    24             6       0
#
# [100 rows x 3 columns]

# %%
# count ---> count taotal num of rows in each columns
s = df .count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            27
# resume_score     9
# placed           1
# dtype: int64

# %%
p = df.min()
p
# Out:
# cgpa            23
# resume_score     4
# placed           0
# dtype: int64

# %%
g = df.filter (items = ['cgpa','placed'])
g

# same
df[['cgpa','placed']]
# Out:
#     cgpa  placed
# 0     26       1
# 1     24       0
# 2     26       1
# 3     24       1
# 4     25       1
# ..   ...     ...
# 95    24       0
# 96    26       1
# 97    24       0
# 98    26       1
# 99    24       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6],axis = 0)  ### axis = 0 in pandas is row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    26             6       1
# 6    23             7       0

# %%
# rename a columns
p = df.rename(columns = {"cgpa" :"updated_cgpa","resume_score" :"sem_marks"})
p
# Out:
#     updated_cgpa  sem_marks  placed
# 0             26          6       1
# 1             24          5       0
# 2             26          8       1
# 3             24          7       1
# 4             25          7       1
# ..           ...        ...     ...
# 95            24          6       0
# 96            26          7       1
# 97            24          7       0
# 98            26          5       1
# 99            24          6       0
#
# [100 rows x 3 columns]

# %%
df['half'] = df['cgpa'].where(df['cgpa'] > 24 ,other = 0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0    26             6       1    26
# 1    24             5       0     0
# 2    26             8       1    26
# 3    24             7       1     0
# 4    25             7       1    25
# 5    26             6       1    26
# 6    23             7       0     0
# 7    24             6       0     0
# 8    24             6       0     0
# 9    25             7       1    25

# %%
df = pd.read_csv("/content/covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.groupby("has_covid").size()
# Out:
# has_covid
# No     55
# Yes    45
# dtype: int64
